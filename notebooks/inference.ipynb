# %% [markdown]
# # Sports Ball Recognizer
# The goal of this project is to classify 19 different types of Sports Ball are played in different sports all over the world. The types are following: <br/>
# 1. Soccer Ball
# 2. American Football
# 3. Tennis Ball
# 4. Base Ball
# 5. Volleyball
# 6. Bowling Ball
# 7. Golf Ball
# 8. Beach Ball
# 9. Pool Ball
# 10. Hockey Puck
# 11. Badminton
# 12. Water Polo
# 13. Squash
# 14. Wiffleball
# 15. Cricket Ball
# 16. Sepak Takraw
# 17. Table Tennis Ball
# 18. Basket Ball
# 19. Lawn Bowls

# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Dokkho/Capstone Project 2_Image Classifier
# Out:
# /content/drive/MyDrive/Dokkho/Capstone Project 2_Image Classifier

# %%
version = 2
img_path = 'test_images'
model_path = f'models/sportballs-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** Soccer Ball

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Soccer Ball',
#  tensor(12),
#  tensor([5.7042e-06, 8.1901e-06, 5.5021e-06, 3.2220e-06, 1.1909e-07, 6.3662e-07,
#          2.1054e-07, 1.2919e-07, 8.7130e-05, 2.8437e-08, 1.2775e-06, 8.1275e-06,
#          9.9972e-01, 2.1302e-07, 1.9418e-09, 2.2145e-06, 8.9043e-05, 6.7444e-05,
#          9.1079e-07]))

# %% [markdown]
# # Inference 2
#
# **Target:** Cricket Ball

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Cricket Ball',
#  tensor(5),
#  tensor([2.4087e-06, 5.7566e-06, 2.9834e-05, 5.4120e-08, 2.5748e-07, 9.9980e-01,
#          4.4433e-07, 9.7806e-05, 4.9300e-05, 2.3764e-08, 1.7609e-07, 5.6621e-07,
#          3.4212e-07, 2.5666e-08, 4.2898e-07, 1.0125e-05, 1.8130e-07, 2.2027e-07,
#          1.5737e-07]))

# %% [markdown]
# # Inference 3
# **Target:** tennis Ball

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x87>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Tennis Ball',
#  tensor(15),
#  tensor([1.6880e-08, 3.0093e-09, 2.8457e-09, 3.7827e-10, 1.7397e-10, 1.0396e-07,
#          2.6232e-07, 5.8667e-10, 3.3971e-10, 1.8625e-08, 1.0982e-08, 5.9709e-09,
#          1.3520e-08, 3.3177e-09, 1.2522e-08, 1.0000e+00, 2.0540e-08, 4.2263e-08,
#          4.9085e-09]))

# %% [markdown]
# # Inference 4
# **Target:** Base Ball

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Base Ball',
#  tensor(1),
#  tensor([1.0182e-06, 1.0000e+00, 7.8960e-09, 1.5540e-09, 3.9044e-10, 3.0429e-08,
#          1.2371e-08, 1.1811e-11, 1.3606e-10, 9.6399e-11, 4.0187e-10, 5.6031e-10,
#          2.9328e-07, 2.0725e-12, 2.8040e-10, 4.8918e-10, 1.1461e-10, 5.4304e-11,
#          2.1007e-10]))

# %% [markdown]
# #Inference 5
# **Target**: Waterpool Ball

# %%
img = Image.open(f'{img_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Beach Ball',
#  tensor(3),
#  tensor([2.1576e-06, 9.4020e-06, 1.4083e-04, 9.9984e-01, 8.5766e-07, 1.8646e-07,
#          9.5334e-07, 2.1107e-06, 3.4986e-08, 5.1749e-07, 8.9395e-07, 1.2643e-07,
#          2.0843e-06, 5.2217e-09, 4.2783e-07, 1.8666e-08, 2.6163e-07, 3.4930e-07,
#          2.6990e-07]))

# %% [markdown]
# #Inference 6
# **Target**: Lawn Ball

# %%
img = Image.open(f'{img_path}/unknown_05.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_05.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Lawn Bowls',
#  tensor(8),
#  tensor([3.8244e-10, 3.0117e-10, 8.1775e-11, 2.8837e-09, 1.4216e-08, 2.6575e-07,
#          1.0832e-07, 1.5936e-08, 1.0000e+00, 3.1362e-07, 1.1197e-09, 7.6253e-10,
#          9.2811e-09, 1.9612e-09, 1.1938e-12, 4.9889e-09, 1.6607e-10, 1.4625e-09,
#          5.2150e-09]))
